# %%
import llb

# %%
text = "I've recorded daily rain (1/0). Predict rain tomorrow."
data = {"rain": [1,1,0,0,0,1,1,0,0,1,0,0,1]}
targets = ["next"]

posterior = llb.infer(
    text=text,
    data=data,
    targets=targets,
    api_url="https://api.openai.com/v1/chat/completions",
    api_key="REDACTED_OPENAI_KEY",
    api_model="gpt-4.1-mini",
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 5
#       2 data = {"rain": [1,1,0,0,0,1,1,0,0,1,0,0,1]}
#       3 targets = ["next"]
# ----> 5 posterior = llb.infer(
#       6     text=text,
#       7     data=data,
#       8     targets=targets,
#       9     api_url="https://api.openai.com/v1/chat/completions",
#      10     api_key="REDACTED_OPENAI_KEY",
#      11     api_model="gpt-4.1-mini",
#      12 )
#
# File ~/LLB - Professor Justin Domke/llb/core.py:88, in infer(text, data, targets, api_url, api_key, api_model, n_models, mcmc_num_warmup, mcmc_num_samples, random_seed, llm_timeout, llm_max_retries, llm_retry_backoff, log_marginal_num_inner, log_marginal_num_outer, verbose, auto_print_result)
#      86     if len(failed_models) > 3:
#      87         detail += f"; ... and {len(failed_models) - 3} more"
# ...
