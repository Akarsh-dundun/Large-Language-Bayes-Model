# %%
import llb

# %%
import ostext = "I've recorded daily rain (1/0). Predict rain tomorrow."data = {"rain": [1, 1, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0, 1]}targets = ["next"]posterior = llb.infer(    text=text,    data=data,    targets=targets,    api_url="https://api.openai.com/v1/chat/completions",    api_key=os.environ.get("OPENAI_API_KEY"),    api_model=os.environ.get("OPENAI_MODEL", "gpt-4.1-mini"),    llm_timeout=300,    llm_max_retries=3,)posterior["next"][:10]
