# %%
import llb
import numpy as np

text = (
    "There is training data for a bunch of different cities on random days, along with the temperature for the following day. \
Then, there is test data for a bunch of different days in those same cities. Predict the temperature on the following days. \
Assume different cities tend to have different weather, and weather tends to be similar on neighboring days."
)

data = {
    "num_cities": 5,
    "num_days_train": 10,
    "num_days_test": 10,
    "day1_temp_train": [
        [61.0, 74.9, 61.5, 73.2, 78.1, 69.8, 55.2, 74.2, 53.9, 75.0],
        [73.0, 78.5, 80.2, 78.9, 82.0, 84.2, 79.0, 81.3, 77.3, 76.0],
        [79.3, 82.1, 82.2, 76.0, 81.2, 84.9, 79.0, 79.6, 81.1, 85.7],
        [81.0, 76.5, 82.0, 78.8, 77.6, 77.1, 76.9, 82.2, 83.7, 78.5],
        [79.8, 78.8, 77.8, 79.6, 76.8, 75.4, 80.4, 75.6, 81.0, 76.2],
    ],
    "day2_temp_train": [
        [61.5, 69.9, 62.0, 73.4, 78.8, 68.8, 53.1, 74.5, 49.4, 76.2],
        [76.4, 78.0, 82.4, 78.9, 80.2, 82.8, 79.4, 79.1, 78.3, 80.0],
        [79.5, 83.8, 77.9, 76.8, 78.5, 85.2, 79.8, 81.6, 80.0, 85.5],
        [80.5, 77.1, 86.2, 78.2, 75.5, 79.1, 78.9, 81.8, 84.2, 82.7],
        [80.8, 78.5, 75.7, 76.1, 74.0, 80.3, 81.6, 77.8, 79.5, 72.8],
    ],
    "day1_temp_test": [
        [69.3, 77.5, 74.8, 65.3, 58.5, 87.0, 54.9, 48.5, 59.4, 72.9],
        [76.5, 48.2, 84.1, 66.6, 85.1, 81.9, 81.0, 77.4, 71.9, 77.7],
        [80.6, 78.9, 79.4, 84.3, 80.5, 81.7, 80.6, 82.7, 82.2, 79.7],
        [82.7, 74.7, 82.1, 77.9, 82.5, 76.2, 81.8, 76.5, 79.1, 82.1],
        [78.4, 75.1, 81.0, 75.0, 74.5, 74.2, 80.5, 76.5, 79.0, 77.8],
    ],
}

targets = ["day2_temp_test"]

posterior = llb.infer(
    text=text,
    data=data,
    targets=targets,
    api_url="https://api.openai.com/v1/chat/completions",
    api_key="OPENAI_API_KEY",
    api_model="gpt-4.1-mini",
    n_models=50,
    mcmc_num_warmup=100,
    mcmc_num_samples=500,
)

pred = np.asarray(posterior["day2_temp_test"], dtype=float)
print("Posterior target keys:", list(posterior.keys()))
print("day2_temp_test sample shape:", pred.shape)
print("Posterior mean (first 10):", np.asarray(np.mean(pred, axis=0)).reshape(-1)[:10])
# Out:
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_1'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_2'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_3'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_4'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_5'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_6'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_7'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_8'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_9'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# /Users/hoanghiepg6/LLB - Professor Justin Domke/llb/mcmc_log.py:42: UserWarning: Missing a plate statement for batch dimension -2 at site 'obs_day2_train_10'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.
#   mcmc.run(jax.random.PRNGKey(rng_seed), data=data)
# Number of requested models: 50
# Number of generated models: 48
# Number of deduplicated models: 0
# Number of invalid models (syntax/parsing): 2
# Number of generation request failures (timeout/network/API): 0
# Number of models missing required targets: 0
# Number of models that failed to compile: 0
# Number of models that failed during inference: 40
# Number of models dropped due to target shape mismatch: 1
# Number of models dropped due to non-finite log bound: 0
# Number of valid models used in final aggregation: 7
# --- Model Averaging Summary ---
# Target: day2_temp_test
# Number of models: 7
# flat mean prediction shape: (5, 10)
# flat mean prediction first_10: [59.2958078791579, 66.25719004883244, 64.00744042263472, 55.874724504600685, 50.039435195591565, 74.04188503496721, 46.9231497453217, 41.59895202149983, 50.769043470589715, 62.19018810367278]
# weighted mean prediction shape: (5, 10)
# weighted mean prediction first_10: [68.76203977203369, 77.66899575805664, 74.87655171203613, 64.4657289352417, 57.16564340972901, 87.80830987548828, 53.19855407714844, 46.36380236053467, 57.94064041900635, 72.66915080261231]
# Difference (weighted - flat) first_10: [9.46623189287579, 11.411805709224197, 10.869111289401417, 8.591004430641014, 7.126208214137442, 13.766424840521069, 6.275404331826735, 4.764850339034844, 7.171596948416635, 10.478962698939526]
#
# Top 5 models by weight for target 'day2_temp_test':
# model=0, weight=1.000000, mu_i_shape=(5, 10), mu_i_first10=[68.76203977203369, 77.66899575805664, 74.87655171203613, 64.4657289352417, 57.16564340972901, 87.80830987548828, 53.19855407714844, 46.36380236053467, 57.94064041900635, 72.66915080261231]
# model=6, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[68.44345739746093, 76.64345434570312, 73.94345739746093, 64.44345738983154, 57.64345417785645, 86.14345434570312, 54.043455703735354, 47.64345417785645, 58.543455703735354, 72.04345587158203]
# model=4, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[69.99759072875976, 77.39418312072753, 74.97138089752197, 66.3295456085205, 59.723095809936524, 84.72049465942384, 55.98602555847168, 50.66813269042969, 60.24549828338623, 72.16570138549805]
# model=2, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[69.304314163208, 77.24028842163086, 74.62722546386719, 65.43310542297364, 58.85204807281494, 86.43440803527832, 55.36796202850342, 49.174027122497556, 59.723071517944334, 72.78839982604981]
# model=3, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[69.16623086547851, 77.46772010803222, 74.7343050994873, 65.11672227478027, 58.23255470275879, 87.08530302429199, 54.58799844360352, 48.10878326416016, 59.14369560241699, 72.81078706359864]
# 2 least-weighted models for target 'day2_temp_test':
# model=1, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[0.7836044720374048, 0.8986732068173587, 1.0046712076496334, 0.5618747548609972, 0.41594339520297946, 0.4923558435253799, 0.4914468836337328, 0.5931096613630652, 0.6794588656611741, 0.7837028646254912]
# model=5, weight=0.000000, mu_i_shape=(5, 10), mu_i_first10=[68.61341775512696, 76.48701538085938, 73.89449118041992, 64.7726371459961, 58.243306800842284, 85.60886946105957, 54.78660552215576, 48.64135487365723, 59.10748390197754, 72.07011891174317]
#
# --- Weighted Posterior Summary ---
# Target: day2_temp_test
# weighted mean prediction shape: (5, 10)
# weighted mean prediction first_10: [68.7892215183803, 77.67337268502372, 74.89758366830009, 64.44522068241665, 57.19990476553781, 87.85939157976424, 53.21362182072231, 46.38751821790423, 57.9444182270595, 72.70860404314314]
#
# --- Weighted vs Flat Target Summary ---
# Target: day2_temp_test
# flat mean prediction shape: (5, 10)
# flat mean prediction first_10: [60.144942455810096, 67.2521024612779, 64.89245564607317, 56.6239910498602, 50.70671965084837, 75.12423936836528, 47.59167754833187, 42.145828941702845, 51.44916806180243, 63.061008489001146]
# weighted mean prediction shape: (5, 10)
# weighted mean prediction first_10: [68.7892215183803, 77.67337268502372, 74.89758366830009, 64.44522068241665, 57.19990476553781, 87.85939157976424, 53.21362182072231, 46.38751821790423, 57.9444182270595, 72.70860404314314]
# difference (weighted - flat) first_10: [8.644279062570206, 10.421270223745822, 10.005128022226913, 7.821229632556445, 6.493185114689439, 12.735152211398955, 5.6219442723904365, 4.2416892762013845, 6.495250165257069, 9.647595554141994]
#
# Posterior target keys: ['day2_temp_test']
# day2_temp_test sample shape: (3500, 5, 10)
# Posterior mean (first 10): [68.78922152 77.67337269 74.89758367 64.44522068 57.19990477 87.85939158
#  53.21362182 46.38751822 57.94441823 72.70860404]
